# %%
pip install torch
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# Requirement already up-to-date: pip in c:\users\sumedha\anaconda3\lib\site-packages (20.2.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sentencepiece
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn

# %%
pip install sacrebleu
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !git clone https://github.com/OpenNMT/OpenNMT-py.git
# Out:
# Cloning into 'OpenNMT-py'...

# %%
cd OpenNMT-py
# Out:
# C:\Users\Sumedha\Desktop\SATHYA-NMT\OpenNMT-py

# %%
# %run setup.py install
# Out:
# C:\Users\Sumedha\anaconda3\lib\site-packages\setuptools\distutils_patch.py:25: UserWarning: Distutils was imported before Setuptools. This usage is discouraged and may exhibit undesirable behaviors or errors. Please use Setuptools' objects directly or at least import Setuptools first.
#   warnings.warn(
# running install
# running bdist_egg
# running egg_info
# creating OpenNMT_py.egg-info
# writing OpenNMT_py.egg-info\PKG-INFO
# writing dependency_links to OpenNMT_py.egg-info\dependency_links.txt
# writing entry points to OpenNMT_py.egg-info\entry_points.txt
# writing requirements to OpenNMT_py.egg-info\requires.txt
# writing top-level names to OpenNMT_py.egg-info\top_level.txt
# writing manifest file 'OpenNMT_py.egg-info\SOURCES.txt'
# reading manifest file 'OpenNMT_py.egg-info\SOURCES.txt'
# writing manifest file 'OpenNMT_py.egg-info\SOURCES.txt'
# installing library code to build\bdist.win-amd64\egg
# running install_lib
# running build_py
# creating build
# creating build\lib
# ...

# %%
pip install -r requirements.opt.txt
# Out:
# ...
#   Cloning https://github.com/NVIDIA/apex.git (to revision 700d6825e205732c1d6be511306ca4e595297070) to c:\users\sumedha\appdata\local\temp\pip-req-build-fxrnwvha
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Sumedha\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Sumedha\\AppData\\Local\\Temp\\pip-install-keqr97ww\\numba\\setup.py'"'"'; __file__='"'"'C:\\Users\\Sumedha\\AppData\\Local\\Temp\\pip-install-keqr97ww\\numba\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\Sumedha\AppData\Local\Temp\pip-wheel-57bnjkab'
#        cwd: C:\Users\Sumedha\AppData\Local\Temp\pip-install-keqr97ww\numba\
#   Complete output (656 lines):
#   TBB not found
#   OpenMP disabled
#   running bdist_wheel
#   running build
# ...

# %%
cd ..
# Out:
# C:\Users\Sumedha\Desktop\SATHYA-NMT

# %%
import os
import sys
import codecs
import sentencepiece as spm
from sklearn.model_selection import train_test_split
import subprocess

# %%
f = open('rawdata.en',encoding="utf-8")
eng_data = f.readlines()  # Returns a list object

# %%
f = open('rawdata.hi',encoding="utf-8")
hin_data = f.readlines()

# %%
len(hin_data), len(eng_data)
# Out:
# (1609682, 1609682)

# %%
src_lang = 'en'
trg_lang = 'hi'
src = {}
trg = {}

src1m = hin_data
trg1m = eng_data
len(src1m),len(trg1m)
# Out:
# (1609682, 1609682)

# %%
src['train'], src['test'], trg['train'], trg['test'] = train_test_split(src1m, trg1m, shuffle=True, test_size=2000, random_state=42)
src['dev'], src['test'], trg['dev'], trg['test'] = train_test_split(src['test'], trg['test'], shuffle=True, test_size=1000, random_state=42)

# %%
for split in src:
    with codecs.open(os.path.join('', f'data/{src_lang}-{trg_lang}', split + f'.{src_lang}'), 'w', 'utf8') as srcOutFile, codecs.open(os.path.join('', f'data/{src_lang}-{trg_lang}', split + f'.{trg_lang}'), 'w', 'utf8') as trgOutFile, codecs.open(os.path.join('', f'data/{src_lang}-{trg_lang}', split+f'concat.{src_lang}.{trg_lang}'), 'w', 'utf8') as concatenatedOutFile:
        srcOutFile.write(''.join(src[split]))
        trgOutFile.write(''.join(trg[split]))
        concatenatedOutFile.write(''.join(src[split]))
        concatenatedOutFile.write(''.join(trg[split]))

# %%
cd data
# Out:
# C:\Users\Sumedha\Desktop\SATHYA-NMT\data

# %%
cd en-hi
# Out:
# C:\Users\Sumedha\Desktop\SATHYA-NMT\data\en-hi

# %%
f = open('test.hi',encoding="utf-8")
hi = f.readlines()
f = open('test.en',encoding="utf-8")
en = f.readlines()

len(hi),len(en)
# Out:
# (1000, 1000)

# %%
hi[900],en[900]
# Out:
# ('acceptance of tender\n', 'निविदा की स्वीकृति\n')

# %%
cd ..
# Out:
# C:\Users\Sumedha\Desktop\SATHYA-NMT

# %%
# %run spmmodel-create.py hi

# %%
pip install OpenNMT-py
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: OpenNMT-py in c:\users\sumedha\anaconda3\lib\site-packages\opennmt_py-2.0.0rc2-py3.8.egg (2.0.0rc2)
# ...
#
# ...

# %%
# %run build_vocab.py -config config_vocab.yml
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\Desktop\SATHYA-NMT\build_vocab.py in <module>
# ----> 1 from onmt.bin.build_vocab import main
#       2
#       3
#       4 if __name__ == "__main__":
#       5     main()
#
# ModuleNotFoundError: No module named 'onmt.bin.build_vocab'

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 2CFE-C5DA
#
#  Directory of C:\Users\Sumedha\Desktop\SATHYA-NMT
#
# 24-11-2020  08:30    <DIR>          .
# 24-11-2020  08:30    <DIR>          ..
# 21-11-2020  13:00             1,869 .gitignore
# 22-11-2020  10:02    <DIR>          .ipynb_checkpoints
# 24-11-2020  02:10                77 build_vocab.py
# 24-11-2020  02:10               706 config_vocab.yml
# 22-11-2020  09:39    <DIR>          data
# 24-11-2020  02:10             1,148 data_prep.sh
# 22-11-2020  07:42    <DIR>          environment
# 09-08-2020  15:39       120,951,209 rawdata.en
# 09-08-2020  15:39       298,873,299 rawdata.hi
# 24-11-2020  02:10    <DIR>          sathya-nmt-main
# 24-11-2020  02:10               524 spmmodel-create.py
# 24-11-2020  05:17           130,906 Thesis.ipynb
#                8 File(s)    419,959,738 bytes
#                6 Dir(s)   5,618,831,360 bytes free
